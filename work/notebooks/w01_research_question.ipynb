# %% [markdown]
# <a href="https://colab.research.google.com/github/akinns247/Starter_Notebook247/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/akinns247/Starter_Notebook247/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
# I chose the Content Refresh Prioritization lane because it focuses on identifying web pages that should be reviewed and updated based on their historical performance. This lane interests me because it demonstrates how machine learning can support real business decisions by helping content teams prioritize their work. As someone learning AI, data analysis, and problem solving through the FlyRank AI Internship, I believe this lane provides a practical way to apply machine learning to a real-world decision while developing my analytical skills.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# Research Question
#
# How can historical website performance data help identify pages that should be refreshed?
#
# Unit of Analysis
#
# One web page.
#
# Decision
#
# Identify which pages should be refreshed first.
#
# Action
#
# A content manager updates the recommended pages.
#
# Cost of a Wrong Recommendation
#
# Incorrect recommendations may waste time on the wrong pages while important pages continue to lose traffic.
#
# Why Machine Learning Helps
#
# Machine learning can identify patterns in page performance and help prioritize which pages need attention.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
# ## Quick Look at the Data
#
# The starter dataset contains **30,000 web pages** and **44 features** describing different aspects of page performance, such as search volume, competition, content type, click-through rate (CTR), average position, and engagement metrics. These observations show that the dataset contains enough information to analyze page performance and support content refresh decisions. This makes the Content Refresh Prioritization lane suitable for further investigation over the next seven weeks.

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

df.head()
# Out:
# Rows: 30000
# Columns: 44
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
