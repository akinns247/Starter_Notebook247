# %% [markdown]
# <a href="https://colab.research.google.com/github/akinns247/Starter_Notebook247/blob/main/work/notebooks/w03_data_contract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/akinns247/Starter_Notebook247/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*
# **One row means:** one content page (`content_id`) in one calendar month.
# **Table(s):** the warehouse table that contains page-level search and engagement metrics.
# **Time window:** March 2026 (`month = "2026-03"`), which is a mid-panel month and not the sealed final month.
# **What I would rank:** pages by their priority for content refresh using historical search and engagement signals.
# **One thing I deliberately exclude:** any future or post-refresh performance metric because it would not be available at the decision moment.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*
# ### Features
# - impressions
# - clicks
# - ctr
# - avg_position
# - engagement_rate
#
# ### Label / proxy
# - refresh_priority (a rule-based proxy for pages that may need refreshing)
#
# ### Context
# - content_type
# - main_intent
# - month
#
#  Excluded
# - future_clicks
# - future_impressions
# - any post-refresh performance metric
#
# **Why excluded?** These fields would leak information from the future and make the evaluation unrealistically optimistic.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*
# ### Query 1 — Grain
# I verify that one row really is one `content_id` in one month.
#
# ### Query 2 — Slice size and date span
# I check how many rows are in my March 2026 slice and confirm the month range.
#
# ### Query 3 — Availability
# I filter rows where analytics availability is `IS TRUE` and count how many rows survive.
#
# ### Five-feature frame
#
# - **impressions** — knowable at the decision moment because they are historical Search Console observations.
# - **clicks** — knowable because they were already recorded before any refresh decision.
# - **ctr** — knowable because it is calculated from historical clicks and impressions.
# - **avg_position** — knowable because Search Console reports it for past performance.
# - **engagement_rate** — knowable because it reflects user behavior already collected by analytics.
#
# ### Leakage lesson
#
# I intentionally added a label-derived feature and observed that the score became unrealistically high. I then removed the leaked feature and kept the honest score because only information available before the refresh decision should be used for modeling.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*
# This slice cannot establish the true causal impact of a content refresh. It contains observational historical data rather than a controlled before-and-after experiment. I also analyze only one mid-panel month, so longer seasonal patterns may not be fully represented.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
